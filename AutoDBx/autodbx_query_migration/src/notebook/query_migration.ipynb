# %%
# !pip install sqlglot
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/474.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 471.0/474.3 kB 15.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 10.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import sys
import os
import yaml

# %%
# Add the parent directory (src) to the Python path
sys.path.append(os.path.dirname(os.getcwd()))

# %%
from utility.query_migration_utils import SQLMigrationProcessor

# %%
current_notebook_path = dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()

# Get the directory containing the notebook (remove the notebook filename)
src_directory = '/'.join(current_notebook_path.split('/')[:-2])

# %%
print(src_directory)
# Out:
# /Users/sourya.barnwal@aidetic.in/AutoDbx_Query_Conversion_updated/.bundle/files/src

# %%
# Build the CSV file path
file_path_parameter = f"/Workspace{src_directory}/utility/parameter.yml"

with open(file_path_parameter, "r") as file:
    config = yaml.safe_load(file)

# %%
# Source database type
src_database = config["src"]

# Table mapping configuration
mapping_catalog = config["mapping_catalog"]
mapping_schema = config["mapping_schema"]
mapping_table = config["mapping_table"]

# %%
source_query_folder = f"/Workspace{src_directory}/source_query"
output_folder = f"/Workspace{src_directory}/output"

print(f"Source database: {src_database}")
print(f"Source query folder: {source_query_folder}")
print(f"Output folder: {output_folder}")
print(f"Table mapping table: {mapping_catalog}.{mapping_schema}.{mapping_table}")
# Out:
# Source database: mysql
# Source query folder: /Workspace/Users/sourya.barnwal@aidetic.in/AutoDbx_Query_Conversion_updated/.bundle/files/src/source_query
# Output folder: /Workspace/Users/sourya.barnwal@aidetic.in/AutoDbx_Query_Conversion_updated/.bundle/files/src/output
# Table mapping table: poc_catalog.logging.sqlglot_config

# %%
processor = SQLMigrationProcessor(
    spark=spark, 
    dbutils=dbutils,
    source_query_folder=source_query_folder,
    output_folder=output_folder,
    table_mapping_table=f"{mapping_catalog}.{mapping_schema}.{mapping_table}",
    src_database=src_database,
    target_database = "spark"
)

# %%
processor.run()
# Out:
# Starting SQL Migration Process
# ...
# Loading table mapping configuration...
# Table mapping configuration loaded with 7 entries
# Found 1 SQL files
# Processing 1 new files
#
# Processing file 1/1: 500_mysql_quries.txt
# ----------------------------------------
# Processing file: 500_mysql_quries.txt
# Found 202 queries in 500_mysql_quries.txt
# Query 1 converted successfully
# Query 2 converted successfully
# Query 3 converted successfully
# Query 4 converted successfully
# Query 5 converted successfully
# Query 6 converted successfully
# Query 7 converted successfully
# Query 8 converted successfully
# Query 9 converted successfully
# Query 10 converted successfully
# Query 11 converted successfully
# Query 12 converted successfully
# Query 13 converted successfully
# Query 14 converted successfully
# Query 15 converted successfully
# Query 16 converted successfully
# Query 17 converted successfully
# Query 18 converted successfully
# Query 19 converted successfully
# ...
